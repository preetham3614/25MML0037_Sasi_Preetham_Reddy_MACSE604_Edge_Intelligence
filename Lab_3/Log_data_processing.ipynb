# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"logs_dataset.csv")

# %%
df.shape
# Out:
# (721547, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721547 entries, 0 to 721546
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   @timestamp  721547 non-null  object
#  1   _id         721547 non-null  object
#  2   ip_address  721547 non-null  object
# dtypes: object(3)
# memory usage: 16.5+ MB

# %%
df.head()
# Out:
#                     @timestamp                   _id  ip_address
# 0  July 8th 2019, 14:43:03.000  XswJ0msBoTGddM7vxMDB  10.1.1.285
# 1  July 8th 2019, 14:43:01.000  dKQJ0msB7mP0GwVzvJjz  10.1.2.389
# 2  July 8th 2019, 14:42:59.000  CcwJ0msBoTGddM7vtb8y  10.1.1.415
# 3  July 8th 2019, 14:42:57.000  bKQJ0msB7mP0GwVzrZdT   10.1.1.79
# 4  July 8th 2019, 14:42:55.000  L6QJ0msB7mP0GwVzpZeI   10.1.1.60

# %%
# unique IP Addresses in the log data 

print("Number of unique ip addresses : " , df['ip_address'].nunique())
# Out:
# Number of unique ip addresses :  386

# %%
df['@timestamp'] = (
    df['@timestamp']
    .str.replace(r'(\d+)(st|nd|rd|th)', r'\1', regex=True)
)
df['@timestamp'] = pd.to_datetime(
    df['@timestamp'],
    format='%B %d %Y, %H:%M:%S.%f'
)

# %%
df.sort_values(['ip_address', '@timestamp'], inplace=True)

# %%
df.head(30)
# Out:
#                 @timestamp                   _id ip_address
# 721473 2019-06-09 00:06:09  DBuOOWsB7mP0GwVzhZ9U   10.1.1.1
# 720483 2019-06-09 01:28:39  bB7aOWsB7mP0GwVzDY5G   10.1.1.1
# 719233 2019-06-09 03:12:49  R0w5OmsBoTGddM7vayZT   10.1.1.1
# 719222 2019-06-09 03:13:45  U0w6OmsBoTGddM7vRi8R   10.1.1.1
# 718875 2019-06-09 03:42:39  z01UOmsBoTGddM7vuzyC   10.1.1.1
# 718730 2019-06-09 03:54:45  x01fOmsBoTGddM7vz6d3   10.1.1.1
# 718240 2019-06-09 04:35:35  nk-FOmsBoTGddM7vLRjb   10.1.1.1
# 717685 2019-06-09 05:21:49  N1CvOmsBoTGddM7vhbSz   10.1.1.1
# 717521 2019-06-09 05:35:29  tlG8OmsBoTGddM7vCDDU   10.1.1.1
# 717169 2019-06-09 06:04:49  uFLWOmsBoTGddM7v4zfT   10.1.1.1
# 716960 2019-06-09 06:22:15  j1LmOmsBoTGddM7v2dTC   10.1.1.1
# 716872 2019-06-09 06:29:35  ayntOmsB7mP0GwVzkEuG   10.1.1.1
# 715947 2019-06-09 07:46:39  lCw0O2sB7mP0GwVzHw4H   10.1.1.1
# 715935 2019-06-09 07:47:39  MSw1O2sB7mP0GwVzCRho   10.1.1.1
# 715573 2019-06-09 08:17:49  sVZQO2sBoTGddM7vp_Sz   10.1.1.1
# %%
df['time_diff'] = (df['@timestamp']-df['shift_time']).dt.seconds//60

# %%
df.head()
# Out:
#                 @timestamp                   _id ip_address  \
# 721473 2019-06-09 00:06:09  DBuOOWsB7mP0GwVzhZ9U   10.1.1.1
# 720483 2019-06-09 01:28:39  bB7aOWsB7mP0GwVzDY5G   10.1.1.1
# 719233 2019-06-09 03:12:49  R0w5OmsBoTGddM7vayZT   10.1.1.1
# 719222 2019-06-09 03:13:45  U0w6OmsBoTGddM7vRi8R   10.1.1.1
# 718875 2019-06-09 03:42:39  z01UOmsBoTGddM7vuzyC   10.1.1.1
#
#                 shift_time  time_diff
# 721473                 NaT        NaN
# 720483 2019-06-09 00:06:09       82.0
# 719233 2019-06-09 01:28:39      104.0
# 719222 2019-06-09 03:12:49        0.0
# 718875 2019-06-09 03:13:45       28.0

# %%
df['date'] = df['@timestamp'].dt.date

# %%
df.head()
# Out:
#                 @timestamp                   _id ip_address  \
# 721473 2019-06-09 00:06:09  DBuOOWsB7mP0GwVzhZ9U   10.1.1.1
# 720483 2019-06-09 01:28:39  bB7aOWsB7mP0GwVzDY5G   10.1.1.1
# 719233 2019-06-09 03:12:49  R0w5OmsBoTGddM7vayZT   10.1.1.1
# 719222 2019-06-09 03:13:45  U0w6OmsBoTGddM7vRi8R   10.1.1.1
# 718875 2019-06-09 03:42:39  z01UOmsBoTGddM7vuzyC   10.1.1.1
#
#                 shift_time  time_diff        date
# 721473                 NaT        NaN  2019-06-09
# 720483 2019-06-09 00:06:09       82.0  2019-06-09
# 719233 2019-06-09 01:28:39      104.0  2019-06-09
# 719222 2019-06-09 03:12:49        0.0  2019-06-09
# 718875 2019-06-09 03:13:45       28.0  2019-06-09

# %%
df['weekday'] = df['@timestamp'].dt.weekday

# %%
df.head()
# Out:
#                 @timestamp                   _id ip_address  \
# 721473 2019-06-09 00:06:09  DBuOOWsB7mP0GwVzhZ9U   10.1.1.1
# 720483 2019-06-09 01:28:39  bB7aOWsB7mP0GwVzDY5G   10.1.1.1
# 719233 2019-06-09 03:12:49  R0w5OmsBoTGddM7vayZT   10.1.1.1
# 719222 2019-06-09 03:13:45  U0w6OmsBoTGddM7vRi8R   10.1.1.1
# 718875 2019-06-09 03:42:39  z01UOmsBoTGddM7vuzyC   10.1.1.1
#
#                 shift_time  time_diff        date  weekday
# 721473                 NaT        NaN  2019-06-09        6
# 720483 2019-06-09 00:06:09       82.0  2019-06-09        6
# 719233 2019-06-09 01:28:39      104.0  2019-06-09        6
# 719222 2019-06-09 03:12:49        0.0  2019-06-09        6
# 718875 2019-06-09 03:13:45       28.0  2019-06-09        6

# %%
df['hour'] = df['@timestamp'].dt.hour

# %%
df['is_weekend'] = ((df['weekday'] == 5) | (df['weekday'] == 6)).astype(int)

# %%
df.head()
# Out:
#                 @timestamp                   _id ip_address  \
# 721473 2019-06-09 00:06:09  DBuOOWsB7mP0GwVzhZ9U   10.1.1.1
# 720483 2019-06-09 01:28:39  bB7aOWsB7mP0GwVzDY5G   10.1.1.1
# 719233 2019-06-09 03:12:49  R0w5OmsBoTGddM7vayZT   10.1.1.1
# 719222 2019-06-09 03:13:45  U0w6OmsBoTGddM7vRi8R   10.1.1.1
# 718875 2019-06-09 03:42:39  z01UOmsBoTGddM7vuzyC   10.1.1.1
#
#                 shift_time  time_diff        date  weekday  hour  is_weekend
# 721473                 NaT        NaN  2019-06-09        6     0           1
# 720483 2019-06-09 00:06:09       82.0  2019-06-09        6     1           1
# 719233 2019-06-09 01:28:39      104.0  2019-06-09        6     3           1
# 719222 2019-06-09 03:12:49        0.0  2019-06-09        6     3           1
# 718875 2019-06-09 03:13:45       28.0  2019-06-09        6     3           1

# %%
df['hour_bucket'] = df['hour']//4
# This integer division by 4, so we can analyse 4-hour buckets instead of every single hour

# %%
ip_addr ='ip_address'

# %%
#-This line counts the number of events per IP and stores it in a DataFrame.
#[Counting how many times the user in logging into the computer wrt to ip address]

ip_counts = df.groupby(ip_addr)['@timestamp'].count().reset_index() 

ip_counts
# Out:
#      ip_address  @timestamp
# 0      10.1.1.1        1446
# 1    10.1.1.100        2860
# 2    10.1.1.101        1465
# 3    10.1.1.106        1408
# 4    10.1.1.109        1459
# ..          ...         ...
# 381   10.1.2.86        4307
# 382   10.1.2.89        2826
# 383   10.1.2.90        2904
# 384   10.1.2.95        2868
# 385   10.1.2.99        1423
#
# [386 rows x 2 columns]

# %%
ip_counts = ip_counts.rename(columns={'@timestamp':'total_count'})

# %%
daily_counts = df.groupby([ip_addr,'date'])['@timestamp'].count().reset_index()

# %%
daily_counts = daily_counts.rename(columns={'@timestamp':'daily_counts'})

# %%
daily_counts_avg = daily_counts.groupby(ip_addr).daily_counts.median().reset_index()

# %%
daily_counts_avg.head(5)
# Out:
#    ip_address  daily_counts
# 0    10.1.1.1          40.0
# 1  10.1.1.100          78.0
# 2  10.1.1.101          40.0
# 3  10.1.1.106          35.5
# 4  10.1.1.109          42.5

# %%
weekend_counts = df.groupby([ip_addr, 'is_weekend'])['@timestamp'].count().reset_index()

# %%
weekend_counts
# Out:
#      ip_address  is_weekend  @timestamp
# 0      10.1.1.1           0         975
# 1      10.1.1.1           1         471
# 2    10.1.1.100           0        1960
# 3    10.1.1.100           1         900
# 4    10.1.1.101           0        1006
# ..          ...         ...         ...
# 767   10.1.2.90           1         871
# 768   10.1.2.95           0        1973
# 769   10.1.2.95           1         895
# 770   10.1.2.99           0         978
# 771   10.1.2.99           1         445
#
# [772 rows x 3 columns]
