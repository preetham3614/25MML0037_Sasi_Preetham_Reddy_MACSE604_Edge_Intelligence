# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.7 MB/s eta 0:00:00
# ...

# %%
# import necessary libraries
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import clear_output
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Loading the YOLOv8 model
model = YOLO('yolov8n.pt')

# %%
# Path to your video (Ensure you upload the file to Colab first)
video_path = "/content/132849-754950619_tiny.mp4"
cap = cv2.VideoCapture(video_path)

# %%
# Loop through the video frames
while cap.isOpened():
    ret, frame = cap.read()

    if ret:
        # 4. Run YOLOv8 tracking (Same logic as your code)
        # results is a list, so we take results[0]
        results = model.track(frame, persist=True, tracker="botsort.yaml")

        # 5. Visualize the results
        annotated_frame = results[0].plot()


        clear_output(wait=True) # Clears the previous frame for a smooth video look
        cv2_imshow(annotated_frame) # Colab's replacement for cv2.imshow

        # Optional: Break if you want to stop early (manual stop in Colab)
    else:
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_483/1021678936.py in <cell line: 0>()
#       6         # 4. Run YOLOv8 tracking (Same logic as your code)
#       7         # results is a list, so we take results[0]
# ----> 8         results = model.track(frame, persist=True, tracker="botsort.yaml")
#       9
#      10         # 5. Visualize the results
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in track(self, source, stream, persist, **kwargs)
#     577         kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     578         kwargs["mode"] = "track"
# --> 579         return self.predict(source=source, stream=stream, **kwargs)
#     580
#     581     def val(
#
# ...
